# %% [markdown]
#  https://github.com/googlemaps/google-maps-services-python.

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U googlemaps
# Out:
# Requirement already satisfied: googlemaps in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from googlemaps) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pprintpp
# Out:
# Requirement already satisfied: pprintpp in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (0.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import googlemaps
from pprint import pprint
import time
import dotenv
import os
import pandas as pd

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# %load_ext dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
chave_api = os.getenv("API_KEY")

# %%
chave_api
# Out:
# 'AIzaSyAcBhkwmTzkO-ZcuYMsYeM6IZhvyHlUPHM'

# %%
print(f"Chave API: {chave_api}")
# Out:
# Chave API: AIzaSyAcBhkwmTzkO-ZcuYMsYeM6IZhvyHlUPHM

# %%
cliente = googlemaps.Client(chave_api)

dir(cliente)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_generate_auth_url',
#  '_get',
#  '_get_body',
#  '_request',
#  'addressvalidation',
#  'base_url',
#  'channel',
#  'clear_experience_id',
#  'client_id',
#  'client_secret',
#  'directions',
#  'distance_matrix',
#  'elevation',
#  'elevation_along_path',
#  'find_place',
#  'geocode',
#  'geolocate',
#  'get_experience_id',
#  'key',
#  'nearest_roads',
#  'place',
#  'places',
#  'places_autocomplete',
#  'places_autocomplete_query',
#  'places_nearby',
#  'places_photo',
#  'queries_per_minute',
#  'queries_per_second',
#  'queries_quota',
#  'requests_kwargs',
#  'retry_over_query_limit',
#  'retry_timeout',
#  'reverse_geocode',
#  'sent_times',
#  'session',
#  'set_experience_id',
#  'snap_to_roads',
#  'snapped_speed_limits',
#  'speed_limits',
#  'static_map',
#  'timeout',
#  'timezone']

# %%
endereco_maracana = "Av. Pres. Castelo Branco, Portão 3 - Maracanã, Rio de Janeiro - RJ"

response = cliente.geocode(endereco_maracana)

pprint(response)
# Out:
# [{'address_components': [{'long_name': 'Avenida Presidente Castelo Branco',
#                           'short_name': 'Av. Pres. Castelo Branco',
#                           'types': ['route']},
#                          {'long_name': 'Maracanã',
#                           'short_name': 'Maracanã',
#                           'types': ['political',
#                                     'sublocality',
#                                     'sublocality_level_1']},
#                          {'long_name': 'Rio de Janeiro',
#                           'short_name': 'Rio de Janeiro',
#                           'types': ['administrative_area_level_2',
#                                     'political']},
#                          {'long_name': 'Rio de Janeiro',
#                           'short_name': 'RJ',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': 'Brazil',
#                           'short_name': 'BR',
#                           'types': ['country', 'political']}],
#   'formatted_address': 'Av. Pres. Castelo Branco - Maracanã, Rio de Janeiro - '
#                        'RJ, Brazil',
#   'geometry': {'bounds': {'northeast': {'lat': -22.90876259999997,
#                                         'lng': -43.2149966},
#                           'southwest': {'lat': -22.91174710000002,
#                                         'lng': -43.2383681}},
#                'location': {'lat': -22.910748, 'lng': -43.2259991},
#                'location_type': 'GEOMETRIC_CENTER',
#                'viewport': {'northeast': {'lat': -22.90876259999997,
#                                           'lng': -43.2149966},
#                             'southwest': {'lat': -22.91174710000002,
#                                           'lng': -43.2383681}}},
#   'partial_match': True,
#   'place_id': 'EkFBdi4gUHJlcy4gQ2FzdGVsbyBCcmFuY28gLSBNYXJhY2Fuw6MsIFJpbyBkZSBKYW5laXJvIC0gUkosIEJyYXppbCIuKiwKFAoSCVPnLeJefpkAEf22PSraFUOvEhQKEgmnRe_8W36ZABEXp1z3yEoEPA',
#   'types': ['route']}]

# %%
nome_do_local = "Lojas Renner"

response = cliente.places(query = nome_do_local)

pprint(response)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AeeoHcIlc7obUqUagEM-HYPeRHIwr5R7CXEHfXteBPDjiK0E8VwJoKYTNp_71FHK332gG6FkLPNmgjyYplw1uz2w29oaEpTxtX_-THP2MacQ57Frifh2Umdm6ZH9EdRVwd2mMUhZXbDVYU8ZIG6mxNPpAQmQd235G7K3BJkW7h8vjKx-RkjZAcsAU3ll_8Og2s1NmZXMJj--ts1xbHWSQfNlftEaYD5PSttSLTM_4Odm6btF1tBdcGHZ35BJrSHCckvFmQfFUvcteIUNtyYaj2IXbCL5zojScxpdo352zf7e3R8svQIRt-r2Rm631feG2Xq0CRdldunfJylQUnhTSVqU96gryD5hfEco2H7xg68WbNCf7rfq9_v9NE53oIO65fa8n1N9y51bWgXDhQ',
#  'results': [{'business_status': 'OPERATIONAL',
#               'formatted_address': 'RUA 210, QS 01 Lote 40 - Taguatinga, '
#                                    'Brasília - DF, 72030-110, Brazil',
#               'geometry': {'location': {'lat': -15.8416172, 'lng': -48.0446171},
#                            'viewport': {'northeast': {'lat': -15.84020107010728,
#                                                       'lng': -48.04328357010728},
#                                         'southwest': {'lat': -15.84290072989272,
#                                                       'lng': -48.04598322989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2268,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103858893623278706814">Claudio '
#                                                 'Gonçalves</a>'],
#                           'photo_reference': 'AeeoHcIUixXWygBHJDslCxMUSx-3lSzobiZ2HHyJAivODMyeB8W87zU6w5ZHF7JK6HO1ApmkekO8VFRk6B5YRUDhz9sAm8RYrXfHsB7A_b446T7QzKqFhKU9TOZ9zHG0-gqMw5cpMwtz5vyHgE1YVbH04oJBz-riQbsFTW8FIjzJWWEHhg6fKmKa_2dR9GUrY2PXrTWR-JR2Va5i3Dsw9LLDcFKjZhQV2fjZHod0WCszNp6CBNUa_VE7QePqITwFVlfvIO0hZKoKNO4jGET47BLAgu6GArJ58e_C5nKPi_Khu9fDoN9wGp8',
#                           'width': 4032}],
#               'place_id': 'ChIJddSXeokyWpMRTlnnmmzPjtc',
#               'plus_code': {'compound_code': '5X54+95 Taguatinga, Federal '
#                                              'District, Brasília - Federal '
#                                              'District',
#                             'global_code': '58PH5X54+95'},
#               'rating': 4.3,
#               'reference': 'ChIJddSXeokyWpMRTlnnmmzPjtc',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 6599},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Av. Brasil Norte, 505 - Vila das Acacias, '
#                                    'Anápolis - GO, 75113-570, Brazil',
#               'geometry': {'location': {'lat': -16.3240113, 'lng': -48.9496265},
#                            'viewport': {'northeast': {'lat': -16.32263707010728,
#                                                       'lng': -48.94825332010728},
#                                         'southwest': {'lat': -16.32533672989272,
#                                                       'lng': -48.95095297989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 770,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103043741512003808218">Carlos '
#                                                 'Silva</a>'],
#                           'photo_reference': 'AeeoHcKt6P9FrxhH6qnAGu68k0dOgoKA7R9Ud0uCeATLxXcfYioHE-Nj0ChbLJRM42GmXwJxdW1J1K4LaXHWaAR6_Fggy3cb7vUf-qNouSKJGHEeg9cjlCNchP58ATjoUstUrSCeRErWXULIm-11T60ELv6xu11pQHdkiF9yP47GjzSv8xllg1PnPNTI3qZV2n_4vXS5Qwz3SzpPSH2bdBWfMni1zKvLKup5KlYBBxez3p6CkkqoWFWcq_ggJNndxx0haQe_pKo7jCl-8pY66j6j6H6lkeLkg6OewcFFPqiZvh2gudCv8fc',
#                           'width': 1006}],
#               'place_id': 'ChIJfYHZJ32kXpMRbL0Q-SUgGsg',
#               'plus_code': {'compound_code': 'M3G2+94 Vila das Acacias, '
#                                              'Anápolis - State of Goiás',
#                             'global_code': '58MHM3G2+94'},
#               'rating': 4.2,
#               'reference': 'ChIJfYHZJ32kXpMRbL0Q-SUgGsg',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2725},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'SMAS Trecho 1 - Guará, Brasília - DF, '
#                                    '71219-900, Brazil',
#               'geometry': {'location': {'lat': -15.8333098,
#                                         'lng': -47.95617559999999},
#                            'viewport': {'northeast': {'lat': -15.83178707010728,
#                                                       'lng': -47.95447457010729},
#                                         'southwest': {'lat': -15.83448672989272,
#                                                       'lng': -47.95717422989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106321271931777886650">Rafael '
#                                                 'Soares</a>'],
#                           'photo_reference': 'AeeoHcJobkNxP7ssX7Y_57EYihq4-wDtlFIQJZFee7HsKbWxnNxSwOs1LG1ioeRXwWJ4sTtudGJOnE3ExV15Mm8OhB3HsCLcqXrlLAWjPOQiOOu0znUbtVE5EM3uMeFE6Phm-OPeZfvtzUolQbueo1EgILXqsLKdrYv5XORg-iPBJi1CXFbE8eBaMJDcCyP0IoAPQBpeH1Xb0Mc044W89u0V8rgHpObBTRNEpGNHNzA5YfGZVUf4Dx1BstPm5c_z6kXJRVNm2F4PT0pnhi9SL9Y5X3P_fvqk51FkogByy5ErOSMUXXKJUU8',
#                           'width': 1920}],
#               'place_id': 'ChIJkfcVqqcxWpMR4WmwA_162Mo',
#               'plus_code': {'compound_code': '528V+MG Guará, Brasília - '
#                                              'Federal District',
#                             'global_code': '58PJ528V+MG'},
#               'rating': 4.3,
#               'reference': 'ChIJkfcVqqcxWpMR4WmwA_162Mo',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 5834},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Avenida Rio Verde, 102/104 - Local 71 / '
#                                    '287 - Vila Sao Tomaz, Aparecida de Goiânia '
#                                    '- GO, 74916-260, Brazil',
#               'geometry': {'location': {'lat': -16.7412494, 'lng': -49.275945},
#                            'viewport': {'northeast': {'lat': -16.73965662010728,
#                                                       'lng': -49.27455032010727},
#                                         'southwest': {'lat': -16.74235627989272,
#                                                       'lng': -49.27724997989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100011561155560483867">Gilmara '
#                                                 'Roberto</a>'],
#                           'photo_reference': 'AeeoHcLvBQhI3mdvr6EUE7rbC0MOr8CETRD0nyc5JTYQ425mu6E5__na3nU48N134gp5jxUs6JvGVRit5sXbiTfogWlFJfSHEPQ8iy7AWkuXXVc5wDsK1C7QxRpXtD3fb6Y9pSR8Uwh2T0vhGQD8qrvJQYGc6NoGEnNPMDo6MVOQW0crsOfGHvkvEWgPrLPAnoKsYBfuRiFlwD-qPdmSWQFtg5c1pXbpHRx3dWRUwI3aioD5ihyus8v2UGkSwMFdtGxQXxJINVUWCiQToZDLiNRfGUVlRZz2KooqNzTsE5ceaqiCnJ4r1qc',
#                           'width': 1920}],
#               'place_id': 'ChIJ_5rANmTcYZMRiDp-BVtl-6g',
#               'plus_code': {'compound_code': '7P5F+GJ Vila Sao Tomaz, Goiânia '
#                                              '- State of Goiás',
#                             'global_code': '58MG7P5F+GJ'},
#               'rating': 4.3,
#               'reference': 'ChIJ_5rANmTcYZMRiDp-BVtl-6g',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 5929},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Av. T-10, 1300 - Shopping, Goiânia - GO, '
#                                    '74223-060, Brazil',
#               'geometry': {'location': {'lat': -16.7085316, 'lng': -49.2727459},
#                            'viewport': {'northeast': {'lat': -16.70693637010728,
#                                                       'lng': -49.27092902010727},
#                                         'southwest': {'lat': -16.70963602989272,
#                                                       'lng': -49.27362867989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102877071054534623632">Moises '
#                                                 'Alves</a>'],
#                           'photo_reference': 'AeeoHcJx552KgDaDe6UBS-oTxHjtvfmyfC3i4UheS4tK46GSaVppKbIpDadgCO2yt0TANaZmrUGah2QUtR-nrgHQf191Iqa74V9HROuemTB_TkviBtj6R5FDsAZ2KdeJeoEgi3Cu6ot3966RLAy2zF5eZFZXlTnZkDN32mSAQJj_QtOvEgRguapFZ8odyWvya0DMdkYv2JRPMGwJJ4GP6DCw0zEmdi8HvD1iymFDUksprZORzgK4fbjfYYsO8PTh4HuqfbA31jWDcRddqK77_BDgn0aJhOgsitS_5zyA9IQ-EieujhIoXGI',
#                           'width': 3000}],
#               'place_id': 'ChIJi0pJcyXxXpMRdFdGQXCoUtk',
#               'plus_code': {'compound_code': '7PRG+HW Goiânia, State of Goiás',
#                             'global_code': '58MG7PRG+HW'},
#               'rating': 4.3,
#               'reference': 'ChIJi0pJcyXxXpMRdFdGQXCoUtk',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3228},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Av. Perimetral Norte, s/n - Fazenda '
#                                    'Caveiras, Goiânia - GO, 74573-260, Brazil',
#               'geometry': {'location': {'lat': -16.630307, 'lng': -49.278126},
#                            'viewport': {'northeast': {'lat': -16.62912732010728,
#                                                       'lng': -49.27665677010727},
#                                         'southwest': {'lat': -16.63182697989272,
#                                                       'lng': -49.27935642989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1396,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112729022974548240269">Casal '
#                                                 'à Moda Antiga</a>'],
#                           'photo_reference': 'AeeoHcK34v780Ytcqo0HUW-2mcdrBM6OHnTz6P2dlO4kg04Hrtkd1_Y4NK5PkSI5E8nmJK-3UOIub6pNdkB7pD9hP6uLwL7NVF3Jo38TtcF73AnInCEvuG3u1UWb4ti4s1RUIUHtj9XIxKWnvJQDeOYpFdeh04QFKPjeygtT8pY2SL_nsu-72XJr7GITYUjyi2RoZIuTVskdjJA-ekyNhBOVoNvlkHeQZituiwSpwbLhaxYVYse7l3BtjHFvEr7QNUvY9kU0NDOatlJ0kIuxAIiJkTVEcfYQD-RJcGADTOMj_x1lfs1oe5c',
#                           'width': 1080}],
#               'place_id': 'ChIJkwFLwmTzXpMR5Rf8mBePQ44',
#               'plus_code': {'compound_code': '9P9C+VP Goiânia, State of Goiás',
#                             'global_code': '58MG9P9C+VP'},
#               'rating': 4.3,
#               'reference': 'ChIJkwFLwmTzXpMR5Rf8mBePQ44',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 5258},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Flamboyant Shopping Center - Av. Dep. '
#                                    'Jamel Cecílio, 3300 - Jardim Goiás, '
#                                    'Goiânia - GO, 74810-100, Brazil',
#               'geometry': {'location': {'lat': -16.7096926, 'lng': -49.2362541},
#                            'viewport': {'northeast': {'lat': -16.70841447010728,
#                                                       'lng': -49.23487487010728},
#                                         'southwest': {'lat': -16.71111412989272,
#                                                       'lng': -49.23757452989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 500,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106171134896623490241">Sergio '
#                                                 'Mitter</a>'],
#                           'photo_reference': 'AeeoHcKRoC0xjjs2RylQ8WRZRZhU0Bu3pK2HGHQb23O1pAbK4nFNc_fhAXpnoYNKYOKg4fgvujIVAsURcGK3ISnwf35earxmn8_P1cJxbK9amoy8Rs_LmYkJgURKdU6VleWUamJyKoDL3RMka7p4nnjFg_JSlGZYeAtIGbQ-QC3jVerjF6LujSJxRe5W3JGP_5W17SDIW7m7Fwo1kjbzIcpd_krgVLue5CuWOMDIrSIwOr3ScpixNPSBCc5kxLdDhjEmi9kLWa4VVf5WJeCUwH7ggQlJ5ONVa5KHdFh7b_6ZKr7IsFCLgRM',
#                           'width': 700}],
#               'place_id': 'ChIJacSFX6vxXpMR1g3bBPa5Kok',
#               'plus_code': {'compound_code': '7QR7+4F Jardim Goiás, Goiânia - '
#                                              'State of Goiás',
#                             'global_code': '58MG7QR7+4F'},
#               'rating': 4.3,
#               'reference': 'ChIJacSFX6vxXpMR1g3bBPa5Kok',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 5132},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Shopping Conjunto Nacional SETOR DE '
#                                    'DIVERSOES NORTE CONJUNTO A EUC N° T-133, '
#                                    'Brasília - DF, 71919-540, Brazil',
#               'geometry': {'location': {'lat': -15.7902314, 'lng': -47.8830833},
#                            'viewport': {'northeast': {'lat': -15.78893707010728,
#                                                       'lng': -47.88184207010728},
#                                         'southwest': {'lat': -15.79163672989272,
#                                                       'lng': -47.88454172989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2340,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104764594263100088996">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'AeeoHcICi0SD9rmXggGIBYE0bNfdJtZDraAZNIrT-aigI7HXF_MuHsv7i0E3cbY8Dkc7e0hVex6ucNUrnWLwzxki1ujUhTDP1QVIHRa8BNuTlzw4w3S4kDwGlnByN76s9BE9u6ZOLDm9obGiNF0HmGCO1gacKaBJnuL2csfnorvW3z6C6cDROKPKqd3doI669-FiYm75d00K-1XUASgPqnWnavwnrmw9HcQNFjOxFIazp_KrzrZNIBKDYCBG35cPeVcqgy8QSzxXQExlg6_sUidgETDeqt8gEDLPY1sM9FqAM0JCIfQpRo0',
#                           'width': 4160}],
#               'place_id': 'ChIJAeGapz47WpMRH3-DfpvRG1I',
#               'plus_code': {'compound_code': '6458+WQ Brasília, Federal '
#                                              'District',
#                             'global_code': '58PJ6458+WQ'},
#               'rating': 4.3,
#               'reference': 'ChIJAeGapz47WpMRH3-DfpvRG1I',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1351},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Shopping DF Plaza - Rua Copaíba, Lote 1 '
#                                    'Águas Claras Norte Brasília DF BR '
#                                    '70297-400, R. Copaíba - Águas Claras, '
#                                    'Brasília - DF, Brazil',
#               'geometry': {'location': {'lat': -15.8318535, 'lng': -48.0406583},
#                            'viewport': {'northeast': {'lat': -15.83034522010728,
#                                                       'lng': -48.03930532010727},
#                                         'southwest': {'lat': -15.83304487989272,
#                                                       'lng': -48.04200497989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2592,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114323712616089862007">alice '
#                                                 'souza</a>'],
#                           'photo_reference': 'AeeoHcL8WBnzbgxoYvTMaSYhBrcdgSb1D7o0jlLJmH8jSjGx1oooqOX530eH7MT5J6Nva1UE_E8KrK-FA87JOqLyyM2DdJa9J8zSzPBB04OXbgTiXqRxMPjfCdlTGUSPUSVulVpENXP2soXXpPEUPYTg1cjQDWedGRzsJ2pkMBxxZeKVKgYJDiwtR66-Quy4ZryKJHpE4drzPVGbF0q7fTZ6ECqP0skrBOj9lec3wL4EFFajSgxnplGvrZw8eAh6Gf-xy8jeqk31fy6Ie2SzItvEI5Gn6Ccy-A9Zjn47NTQ_SH00qWafttU',
#                           'width': 4608}],
#               'place_id': 'ChIJS4rx9fUyWpMRSVFsluD7d-U',
#               'plus_code': {'compound_code': '5X95+7P Águas Claras, Federal '
#                                              'District, Brasília - Federal '
#                                              'District',
#                             'global_code': '58PH5X95+7P'},
#               'rating': 4.4,
#               'reference': 'ChIJS4rx9fUyWpMRSVFsluD7d-U',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 930},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'R. 9, 1855 - Shopping Bougainville, '
#                                    'Goiânia - GO, 74150-130, Brazil',
#               'geometry': {'location': {'lat': -16.695228, 'lng': -49.2652932},
#                            'viewport': {'northeast': {'lat': -16.69390592010728,
#                                                       'lng': -49.26421367010727},
#                                         'southwest': {'lat': -16.69660557989272,
#                                                       'lng': -49.26691332989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2268,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107241570987061380477">Marcelo '
#                                                 'Carvalho</a>'],
#                           'photo_reference': 'AeeoHcLwLUU5DI8rf6QmUemCnrdtOy4RxmXaDf244Y0zmREg6JlZ9yDDlUJCBrrt0ax1PEDwYPntRhHszPRJ5yzp6YVXYMHpcJDaag5bHCZrx6Y_eAIXrE01tQczx5bTZpvZbpd9-Jzw7HFZfUqVC3a-KyhMj9YSHEl89xvaa6NJKhmRm8fBW0s9ldJgs_ijjkyc3ldk_gL0BboELCtuH_q2lPA6PROQfFTzDhiUI6j8j3lP-wHGMxLjaSheBGSCbqGD59MS2vLp2-nOW5FemqwBIHYFOuce7t6R2ffNuPQoji6P7RvuRbM',
#                           'width': 4032}],
#               'place_id': 'ChIJfXygdUDxXpMRPcDlEj0PZ48',
#               'plus_code': {'compound_code': '8P3M+WV Goiânia, State of Goiás',
#                             'global_code': '58MG8P3M+WV'},
#               'rating': 4.3,
#               'reference': 'ChIJfXygdUDxXpMRPcDlEj0PZ48',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1404},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Setor Comercial Sul, Loja 520 / 521 / 522 '
#                                    '/ 523 - Asa Sul, Brasília - DF, 70307-902, '
#                                    'Brazil',
#               'geometry': {'location': {'lat': -15.7967572, 'lng': -47.8918404},
#                            'viewport': {'northeast': {'lat': -15.79545252010728,
#                                                       'lng': -47.89068102010727},
#                                         'southwest': {'lat': -15.79815217989272,
#                                                       'lng': -47.89338067989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1868,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114323712616089862007">alice '
#                                                 'souza</a>'],
#                           'photo_reference': 'AeeoHcIEQVpqilozxoq1gSPUYXc7rUPUvExSTI5t-JRKcuJxud6V5m_eVm5z6Ikz6EFis9h1aSiS3oDyt33zUyqBFQy1EpHUsYBwDuGhtzKAOTZtAUX46LUYYnaxiOQ33bFRrTVdVDnKPGaA3JBpvn_pm3-j1BbHkJbhdG33m4Nu853942-d4GHevHSqbMGaRe2SJnAr1lewJbH9N1ctyEEMzfxDGiJcq6ehg1n2kVZi4k-kmhbFR9Iltz41cYKDZQx9zK5Pk7lUO-wKE1oVF4Z5JFuETCW-fuj3cxZ8DqqenSL3k0k6wkc',
#                           'width': 4000}],
#               'place_id': 'ChIJV0M4HpswWpMRHxnQprmS6OU',
#               'plus_code': {'compound_code': '6435+77 Asa Sul, Brasília - '
#                                              'Federal District',
#                             'global_code': '58PJ6435+77'},
#               'rating': 4.3,
#               'reference': 'ChIJV0M4HpswWpMRHxnQprmS6OU',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3966},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'St. de Habitações Individuais Norte CA 4 - '
#                                    'Lago Norte, Brasília - DF, 71503-504, '
#                                    'Brazil',
#               'geometry': {'location': {'lat': -15.7203736, 'lng': -47.8871814},
#                            'viewport': {'northeast': {'lat': -15.71928777010728,
#                                                       'lng': -47.88569197010727},
#                                         'southwest': {'lat': -15.72198742989272,
#                                                       'lng': -47.88839162989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111735550221111236185">Bruno '
#                                                 'Cardoso</a>'],
#                           'photo_reference': 'AeeoHcKePJyVmwQa-YmxnOuvilsqpNzPlc8rUi4mB6n3puRdUJispEKvlLk8rbO9pnON1fr16uvOhlM4nW2gO1QgJaPqsck41C7Hyp66Vv6rvopR_q6WigjONvTLVPNJgxjiwEJ-9vKB89hFL4bRSfB5ajw_6qh3iHwHtnfTuF9ilYuA7yJJuHi_VbT8QU8HFj9NxYHVniWy4FObgYvR_lUxWUTAp4Ad-WFCbBadAwvkNhEvLvtZI-MfSqixF6dYr2fYd2ntGD4tCIRBfwvbUM3w-EDePypmDut3pBA-QRc_QcxsOktU0sk',
#                           'width': 4032}],
#               'place_id': 'ChIJibOHN6E5WpMRCJHKJtgEDsY',
#               'plus_code': {'compound_code': '74H7+V4 Lago Norte, Brasília - '
#                                              'Federal District',
#                             'global_code': '58PJ74H7+V4'},
#               'rating': 4.3,
#               'reference': 'ChIJibOHN6E5WpMRCJHKJtgEDsY',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1038},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Av. Paulo Gracindo, 15 - Piso 2 - Morada '
#                                    'da Colina, Uberlândia - MG, 38411-145, '
#                                    'Brazil',
#               'geometry': {'location': {'lat': -18.9572654, 'lng': -48.2777717},
#                            'viewport': {'northeast': {'lat': -18.95615282010728,
#                                                       'lng': -48.27630407010727},
#                                         'southwest': {'lat': -18.95885247989272,
#                                                       'lng': -48.27900372989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'RENNER',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1150,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110449065373317301447">Paulo '
#                                                 'Leandro Graça Martins</a>'],
#                           'photo_reference': 'AeeoHcLToPlh330Yu0Mvj50M5oLAn3WTaIfZWfU6EHca4dg728LmNP1Y2_ZOZG8ySouqqEX-Y3ySkY92N72gF7X8BVHGzywniSGKaVxQH0ok3CLKO_SfaMYSjLGarHWAQQqG5qY2uGgq3wvQVaDHQcj-SmynwN1gZxQIpdJ-909QIjFM6QqbI9vH4tG0Q_LnFuBDUN8qQBOnU64KKTS68r3QkfhNF7HSUfM0HAplmn2BgZjAgGmg8f8p1s6I6g4FThKpmEVWwqN1TEvTXiUawzP2RpnSsUAdlb7cTk_M6B2z-u3XOaIFOYQ',
#                           'width': 2048}],
#               'place_id': 'ChIJL9KkjCpFpJQRuiFf-5xXP5s',
#               'plus_code': {'compound_code': '2PVC+3V Morada da Colina, '
#                                              'Uberlândia - State of Minas '
#                                              'Gerais',
#                             'global_code': '58HH2PVC+3V'},
#               'rating': 4.4,
#               'reference': 'ChIJL9KkjCpFpJQRuiFf-5xXP5s',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 881},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Shopping Center, Av. João Naves de Ávila, '
#                                    '1331 - Tibery, Uberlândia - MG, 38408-100, '
#                                    'Brazil',
#               'geometry': {'location': {'lat': -18.9098992, 'lng': -48.2616243},
#                            'viewport': {'northeast': {'lat': -18.90897702010727,
#                                                       'lng': -48.25987482010728},
#                                         'southwest': {'lat': -18.91167667989272,
#                                                       'lng': -48.26257447989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2231,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103733214541735605376">William '
#                                                 'Moreira</a>'],
#                           'photo_reference': 'AeeoHcJK8EghGJvNB6DabBu49zEgHSvLRrTKun42S9LbVDzOkYdOLabKStHUZGmD2SAoT8UmAODJYCF4Xb5Q7DfAZhEB1AFpW9G_ePkoVcR13TVarfKjQvOuDS3rDCcgSFMpvwzad1yBXiC9dK9ugXhukpNZZKr9_OhiL-ijP3frFVnYxQZaXpeyoCy6r2yyqXfCAM9ROOmjB7eF0SDjl_6krgD-ZJK5F_w8ZQi-Lci-X35pmK3ZAgDrFLpkxs4zJ8UZcnX8HCzO6030aNe1DLfF1r8cx9wGIoYaoJYWm8S_sOlYc62r2y0',
#                           'width': 2231}],
#               'place_id': 'ChIJW9AQ2KNFpJQRoQaxY9a_r5s',
#               'plus_code': {'compound_code': '3PRQ+29 Tibery, Uberlândia - '
#                                              'State of Minas Gerais',
#                             'global_code': '58HH3PRQ+29'},
#               'rating': 4.3,
#               'reference': 'ChIJW9AQ2KNFpJQRoQaxY9a_r5s',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 5581},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Q. 107 Norte Avenida NS 5, SN - Plano '
#                                    'Diretor Norte, Palmas - TO, 77001-080, '
#                                    'Brazil',
#               'geometry': {'location': {'lat': -10.1838554,
#                                         'lng': -48.34798199999999},
#                            'viewport': {'northeast': {'lat': -10.18236407010728,
#                                                       'lng': -48.34705722010727},
#                                         'southwest': {'lat': -10.18506372989272,
#                                                       'lng': -48.34975687989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103226115555013044079">Flávio '
#                                                 'Henrich</a>'],
#                           'photo_reference': 'AeeoHcIkCV8SDCx2x00D-1OJ2pAoe-P0pVPn5xyoOQqWGONYvQvHqWmkJNpES9sK2RPht1NCm1G3FOkKB8j07OM4DmLyKXC3hr5VbaCdRist-uK8aSIP2-3XJ_xzx30OEMPQggAMm0UppBi5PCLWPQHH0v10UzBbhhVeWARjHPprmC45osa1EDdDdaiqSH7gNnPZVPwmMy4K5vQv9mmYKgI1ijFoeBjeFzkxUtBezcEqSBapYVzvAk-8gl_b-91FYgQZA_zUYVQ06cPKYccxVFkJci4QlI8tGg4Nsvyc9_-6hA5HJzBKePM',
#                           'width': 1920}],
#               'place_id': 'ChIJZXZGbBbLJJMRlp8iK4hTl0M',
#               'plus_code': {'compound_code': 'RM82+FR Plano Diretor Norte, '
#                                              'Palmas - State of Tocantins',
#                             'global_code': '58XHRM82+FR'},
#               'rating': 4.3,
#               'reference': 'ChIJZXZGbBbLJJMRlp8iK4hTl0M',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2208},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'STN BL A - Asa Norte, Brasília - DF, '
#                                    '70715-900, Brazil',
#               'geometry': {'location': {'lat': -15.7336739, 'lng': -47.899254},
#                            'viewport': {'northeast': {'lat': -15.73252172010728,
#                                                       'lng': -47.89784272010728},
#                                         'southwest': {'lat': -15.73522137989272,
#                                                       'lng': -47.90054237989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107815558207003034126">Marcelo '
#                                                 'Teixeira</a>'],
#                           'photo_reference': 'AeeoHcKRXqaIgibHu3o5nTXVVuzwp0rmdG1eaQslthDN1qjd4YToYp8pN-DsbT7d2t0whNN3fpAVhJHTUB1H1aVgJy2CiiPfN3bEOkcsMbHnWRQw022nEOA7whA0P0Vkzgv6supSj8ZUzS9bCjNOlzf6PY_MBgabp4wyW2ZcnwTJmLgz4Fw1CxCxENGARAmQBZuJPkmJUpWJe0v3cn7_wS9-bd-kbDcdVYeX-YdSSCk42pxnf6xW8PkXZRouq2Hv9rQzb32VYsfVQUl3NUdVWgWBVZRKZ3haiYdTryz1U2yaYY5GzM7_JAc',
#                           'width': 1920}],
#               'place_id': 'ChIJtc51z_s6WpMR1qeL2rPMuCI',
#               'plus_code': {'compound_code': '7482+G7 Asa Norte, Brasília - '
#                                              'Federal District',
#                             'global_code': '58PJ7482+G7'},
#               'rating': 4.3,
#               'reference': 'ChIJtc51z_s6WpMR1qeL2rPMuCI',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2270},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'BR-040, 270 - Parque Esplanada III, '
#                                    'Valparaíso de Goiás - GO, 72876-902, '
#                                    'Brazil',
#               'geometry': {'location': {'lat': -16.0801042, 'lng': -47.9843064},
#                            'viewport': {'northeast': {'lat': -16.07875837010728,
#                                                       'lng': -47.98296687010728},
#                                         'southwest': {'lat': -16.08145802989272,
#                                                       'lng': -47.98566652989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 468,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114543934376560607935">Sr. '
#                                                 'Gustavo</a>'],
#                           'photo_reference': 'AeeoHcJRCRB0YQpAF23AQmDX7RmePbz_zOVOesOGCZGXn3Bk9BOLmqKb4ygzhxbdKUcnV2XibwNu6peiz3XMsno76TujC4RJn8wlnrslA0OsP6UdIo0xk4gVDiqUEcVZ-eFFhQaHR2_SQQz0Xt-D9JK4Pfv6Asn6xiJtuPsh5HyIJTHPoKOK2gFaS1aGS8fzlJbc1bYzTgKiZdabcKrT-fxt2pvYwYMS0sOldGZbBqjRlo2Sz44lhb9JQvsMy2aczmPe2ifInfrNHLWpC1qJKQX6thB1vVV4ydU4NDdSDAeoWaVuvzQynrs',
#                           'width': 600}],
#               'place_id': 'ChIJXxZqEBeEWZMRNNoiju0562k',
#               'plus_code': {'compound_code': 'W298+X7 Parque Esplanada III, '
#                                              'Valparaíso de Goiás - State of '
#                                              'Goiás',
#                             'global_code': '58MJW298+X7'},
#               'rating': 4.3,
#               'reference': 'ChIJXxZqEBeEWZMRNNoiju0562k',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 5095},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Av. Anhanguera, 10790 - Shopping Cerrado, '
#                                    'Goiânia - GO, 74435-300, Brazil',
#               'geometry': {'location': {'lat': -16.6660723, 'lng': -49.3088328},
#                            'viewport': {'northeast': {'lat': -16.66456677010728,
#                                                       'lng': -49.30760752010729},
#                                         'southwest': {'lat': -16.66726642989272,
#                                                       'lng': -49.31030717989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2340,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118287901919740616475">Raphael '
#                                                 'Leao</a>'],
#                           'photo_reference': 'AeeoHcIGDlmYsIBVNViAx0IzeK-ORhNvbzNKQvLbqhsPRVdFbQazSUScM-24uu8Y-HYwvxTR-7B4bmJxSe7LI_9NSa9DU-o3AhWN89L4BUF6PE5y96BIwlO52iRxuAj6uw7s9sggX7DPhzxfRH0bakiSewiODyOPMIN6kSCIibu_mJ6ko6RIA_kRQVYTUl_noYX1TeSQGa0gZv3HR438wzvC3L_9Q0afrjCJirNpT0PC0109Qqt2GZ2kCdIUDiqZr6VGuP0EA9JG0JyjXk9WpVjGw3PFazRWXsvKd7VWsBEujOUo_jLBhRg',
#                           'width': 4160}],
#               'place_id': 'ChIJix7yuED0XpMR6m5AjPR3VLE',
#               'plus_code': {'compound_code': '8MMR+HF Goiânia, State of Goiás',
#                             'global_code': '58MG8MMR+HF'},
#               'rating': 4.3,
#               'reference': 'ChIJix7yuED0XpMR6m5AjPR3VLE',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2033},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Shopping Buriti, R. O, 1044, Rio Verde - '
#                                    'GO, 75907-580, Brazil',
#               'geometry': {'location': {'lat': -17.8188883, 'lng': -50.9449336},
#                            'viewport': {'northeast': {'lat': -17.81756592010728,
#                                                       'lng': -50.94295897010728},
#                                         'southwest': {'lat': -17.82026557989272,
#                                                       'lng': -50.94565862989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106031097469856729701">Jhonney '
#                                                 'Negreios</a>'],
#                           'photo_reference': 'AeeoHcIZwxLtt_IEv-QM_H92zAlL1481GCKRkPIXYtqHDg-x3hYFPLRZYHWJzSrRnm9Y1ivXkAYKGid__PgiR9gnB1JIJEYrf67rtt7QbEgh2dgYCNLyKe5wkf1mKL6Mj5-UlH-EeDmPoAkICJdenJZsr9vPVd8Ua6mmkF9B_mVI3F_BVbd-Y3DilHF71zsqYDvkCgSokPC7kF_d7hML9GxxVxh_v-6o7rd5dg2ZAjrC4ReCSlRA3adsfLYy7ZuiVKopRzMeZ4sLUoN9Qre1YwrS-X6tquTNhH-gLSxCB4BE2cZ6AkgMmxQ',
#                           'width': 1920}],
#               'place_id': 'ChIJ1VI3NGTcYZMRuCowbQGfkO4',
#               'plus_code': {'compound_code': '53J4+C2 Rio Verde, State of '
#                                              'Goiás',
#                             'global_code': '58JF53J4+C2'},
#               'rating': 4.4,
#               'reference': 'ChIJ1VI3NGTcYZMRuCowbQGfkO4',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1212},
#              {'business_status': 'OPERATIONAL',
#               'formatted_address': 'Av. Presidente Artur Bernardes, 43 - '
#                                    'Jardim Aeroporto, Várzea Grande - MT, '
#                                    '78125-100, Brazil',
#               'geometry': {'location': {'lat': -15.6528524, 'lng': -56.1226875},
#                            'viewport': {'northeast': {'lat': -15.65170837010728,
#                                                       'lng': -56.12113282010727},
#                                         'southwest': {'lat': -15.65440802989272,
#                                                       'lng': -56.12383247989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Lojas Renner',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 408,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113274190877837243933">nano '
#                                                 'tec</a>'],
#                           'photo_reference': 'AeeoHcI3lrgDAigsYNyw3GhsDWhATO-dU4Q8dbP-cZ2kgQVY7rqLC6vDvljjdsenNo6-iiiV5hiJkBM9THJVXfdFgoOU23A7fWlkv1zrzs5Ro9CJs-j_sm_P13fNMo6GCyL2BKqvTn54D4VTBE5TcqjxrN2-5qNELr5S5Jz2AJh8xKMD3DXDmp-wxJd39BqLMoY7xkj3wOnUQU2zyH5B1WPscJQ4G-7l1L0VCiFc7jbl6_CFCw3JM32oNRg-Wo0FgOiTl6s21YHAvzIv_SQeo9haAalBf8x-vIQuwwlyZ20I1ZylwtiCkmc',
#                           'width': 720}],
#               'place_id': 'ChIJR5PjpdutnZMRknzivnEpfE8',
#               'plus_code': {'compound_code': '8VWG+VW Jardim Aeroporto, Várzea '
#                                              'Grande - State of Mato Grosso',
#                             'global_code': '58P58VWG+VW'},
#               'rating': 4.4,
#               'reference': 'ChIJR5PjpdutnZMRknzivnEpfE8',
#               'types': ['clothing_store',
#                         'shoe_store',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3066}],
#  'status': 'OK'}

# %%
coordenada_maracana = (-22.9087371, -43.2381983)

results = cliente.places_nearby(location = coordenada_maracana, 
                                  keyword = "Lojas Renner", radius = 50000)

results
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AeeoHcJTdgvrfI1sXzWB2lK5Wa_vNj43dDyjTExkboppkiaNn9haLxe6g8v6UmK0IRBfxfCsRRTAhE0AL3F6MeWXkYKA_OIu6NjplMv975IXyILxktUr4lGj5yzqW_AZ4I7FCvVP2sP1vIVY3zIw_pp_RSztvbdalKKLgnkktpneUN9HVcvPwDXTmXOrqrLJhOrS6JYHtwOmXNq9vdoBT8rXlWkiGtQaPsXpAdxGXyYp_8IfGtBOaCTiP_IDkD5tnGRQwksc7LyFm4hkyj0R6vTI16yeD7baASTrRFGcl1_2ItX620ABGTJIU9rYjqQvyzRaXrwqFMIanWaNLYCYP_W5UcZohs-FemtjO_5HYdtFtME30JJ48SEzzfnqfP0ih2dk0lpBWobewBLdcYbrr1o4mTJ1Xj5AbsKepdCRLqoysQt0TMS1X2dHbBqjN0_URx8',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9573279, 'lng': -43.17676609999999},
#     'viewport': {'northeast': {'lat': -22.95602882010728,
#       'lng': -43.17535502010728},
#      'southwest': {'lat': -22.95872847989272, 'lng': -43.17805467989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107660623993280425078">Eduardo Amorim</a>'],
#      'photo_reference': 'AeeoHcItmeRt5WaMiHHrE7SakS2OxHZU4i4VTz68mxgx0KrhBv4DHy2DMSSnuIFOuVndNqnVPDy6_Jzj9LIyGUCBMLuEaDIbs2Y5lo0zH9jFfLGv8gKcXzdInugVA5_ge_hbKnFWJT09SW1zK06F6kD8hsLwLEaqa8f_yP1wS83ski3USXgLmKQzHDb0XPMuNME6SCW8eFtFpl_eTTN0dmQ6omcybqbfZJzBFPMJuQxF9hcttqnaTfL5aamGk-PzTTAqWGMa0VP8pt2ZOv5TA0aoqYBX37xWkF32mWC1MkEBeL83zfXqQ5k',
#      'width': 5312}],
#    'place_id': 'ChIJGbC2UPh_mQAReYXaxj6lQSE',
#    'plus_code': {'compound_code': '2RVF+37 Botafogo, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R2RVF+37'},
#    'rating': 4.3,
#    'reference': 'ChIJGbC2UPh_mQAReYXaxj6lQSE',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4254,
#    'vicinity': 'Rua Lauro Müller, 116 - Pisos 1 e 2, AB13 - Botafogo, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9327368, 'lng': -43.1771487},
#     'viewport': {'northeast': {'lat': -22.93150537010727,
#       'lng': -43.17578527010728},
#      'southwest': {'lat': -22.93420502989272, 'lng': -43.17848492989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3006,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112421767188917869647">Deny Tanizaki</a>'],
#      'photo_reference': 'AeeoHcKOAFVaD6jTdgzB2PzMCgCRi6NaG5abTQOZnwubvcjtyC7DpHk_q7A4kGzoutlPyvFg-WRmiQb_BrXUlzggB9fiUNWnAtRFmZv98x6e-hGSl110omySM_fPcOuCIEyF07bFrI2DLr3JDX6IhJn-hibeoSGs_hRLE4hpHvZp9-eL6sRHHAlTcg5XuZD9_HBccwMHcasJ_WMOlKRGUxrsR2jYqRh9LSQdovUMF-BKW3pRvNEcWm_6DTocVa5PQuWfKBJUP0J9q45Acx0r1onZRn5aQDVZphTxQ5qtXRvPFTEYKSe8mJk',
#      'width': 5344}],
#    'place_id': 'ChIJaVMX-IZ_mQAR1H-aprYXNVA',
#    'plus_code': {'compound_code': '3R8F+W4 Flamengo, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R3R8F+W4'},
#    'rating': 4.3,
#    'reference': 'ChIJaVMX-IZ_mQAR1H-aprYXNVA',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4631,
#    'vicinity': 'R. do Catete, 359 - Flamengo, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.8963189, 'lng': -43.1235264},
#     'viewport': {'northeast': {'lat': -22.89503182010727,
#       'lng': -43.12271762010727},
#      'southwest': {'lat': -22.89773147989272, 'lng': -43.12541727989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102147819262356148509">heleno</a>'],
#      'photo_reference': 'AeeoHcJmbFAPiWW_MhAnAeKEWQ1fBtqH1omrwaUdNZ5pXajbghZ6ETZPNgB15r9BonYmIOrlrAnXmvHNtntlY5oEuX0Ysw0jVCOjYLsFkZ4TSarLaXuPV62AnPj__XCk3IixThqU7yLmVZjPP6HTaOnIuva4FYK6SokJFb-nWk5W9BrWYt2ufYiT4Wdre4FjXeodK8KOOEMQYn5ISMQ4T4DJvHEFHk8tjR4KEh4YckKBX2Iuu7Lc6SgAvyCWwlOyW029wm80migqrJxySUyJN_BQhJgvLqov_zIvoanWx108KNPmHRRCZrQ',
#      'width': 1920}],
#    'place_id': 'ChIJf6hb1tqDmQARSjOe6gQVdTs',
#    'plus_code': {'compound_code': '4V3G+FH Niterói, State of Rio de Janeiro',
#     'global_code': '589R4V3G+FH'},
#    'rating': 4.3,
#    'reference': 'ChIJf6hb1tqDmQARSjOe6gQVdTs',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 11311,
#    'vicinity': 'Rua Quinze de Novembro, 8 - Shopping Plaza, Niterói'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.972719, 'lng': -43.1878736},
#     'viewport': {'northeast': {'lat': -22.97130902010728,
#       'lng': -43.18656252010727},
#      'southwest': {'lat': -22.97400867989272, 'lng': -43.18926217989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112998749160755258753">Rafael Gomez</a>'],
#      'photo_reference': 'AeeoHcIxE6hQBsqUkbijiUcvHdi3c1-Eah5ADaFiJnvkzL8XehaVwIt57yaEaHqCj6lJxdYS6OYw9f4Ob4sbGN-zPZRN2V7J3DpF6Ww3npJTO_8Q1RdXMNWWu6k72FKCIQxSonZe5hC3b70kIc2ZxGimDGkZiAXvUHO0YgJwoGSrwz-4tZO4CImwJe_JaxPggtJVKlbTT_oU5Ju0dEvgNXtmGf47LRPSpjd7_f4aiu4KzZs5r1TAulC6UyHSOZrCG2UniQulT02BJ5-brhdYP1DMckwh32MJB_8zaL5Wm6iqztMvURp00L8',
#      'width': 4032}],
#    'place_id': 'ChIJhVgkXUTVmwARqBoJch3kuxw',
#    'plus_code': {'compound_code': '2RG6+WV Copacabana, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R2RG6+WV'},
#    'rating': 4.3,
#    'reference': 'ChIJhVgkXUTVmwARqBoJch3kuxw',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 3326,
#    'vicinity': 'Av. Nossa Sra. de Copacabana, 759 - Copacabana, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.997582, 'lng': -43.3592343},
#     'viewport': {'northeast': {'lat': -22.99585332010728,
#       'lng': -43.35817287010728},
#      'southwest': {'lat': -22.99855297989272, 'lng': -43.36087252989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2340,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102910049610745399249">Alexandre Oliveira</a>'],
#      'photo_reference': 'AeeoHcKorP2OsFXLA3rgBK-qYHY7DwH73FMqDlkYJDZQgg-iPFsebss0DKHKPCIKWHFgDnGBCfPNtr8XSLja4NDOdi9PqvsrqRllXi-c0CZc7WvoArHH962CM_hbnkJ-e1ReZnsFcxgYaNMoFdV4oI3stGoCMtnIH17zOAk8_ZmIeViLIZ6Pn9JDNrOiVN6ZD5W3dPAocpMLjmA-QJ6CAb3p4MayNdOfAZsdbWJLB-WxNwCgSO-tkZHVw7mzjaPZQqoYFtt-rtqCFXS7dVMxSMEMAfg2gqMNYf51gbpurDxJb8YGkI0SLQQ',
#      'width': 4160}],
#    'place_id': 'ChIJNQyBdbvQmwARXZeIAKdhLKE',
#    'plus_code': {'compound_code': '2J2R+X8 Barra da Tijuca, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R2J2R+X8'},
#    'rating': 4.4,
#    'reference': 'ChIJNQyBdbvQmwARXZeIAKdhLKE',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 5591,
#    'vicinity': 'Av. das Américas, 4666 - Loja G - Barra da Tijuca, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.7984894, 'lng': -43.3508919},
#     'viewport': {'northeast': {'lat': -22.79656157010728, 'lng': -43.35019905},
#      'southwest': {'lat': -22.79926122989272, 'lng': -43.35297045000001}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100563369761867803895">Dejalmir Lima</a>'],
#      'photo_reference': 'AeeoHcJMuf142EmPDG_d3h6Fd-YnH5ijJwRtDhpP2zzMKl63nGguYy213PGcsdNNsFS4M-Z6Bupl4V4Y0Zpjbd3GjzhcslHQpmZGzgqgT_TYxiHf71J25g40-0cbpQ-LuMJ6NL2L8qtXBYcLkRhoWyu50NDpUsH2-E85OFOLErRWEqLGaxKJwp7J2-65OjUsdF2viW-Wc1KQCW0QydUDX1dc-SQdXgf5qP3B3KwrHSFt-Rv5wtYO2mDJRYu4vIoc3EkaAzS2MJ3kQBRY2YlIzSQMRoXQXkf1j6nEYdBgl5vvIKhSHNqsQic',
#      'width': 1920}],
#    'place_id': 'ChIJnzrGqudkmQARDmKtn8rxfTs',
#    'plus_code': {'compound_code': '6J2X+JJ Centro, São João de Meriti - State of Rio de Janeiro',
#     'global_code': '589R6J2X+JJ'},
#    'rating': 4.4,
#    'reference': 'ChIJnzrGqudkmQARDmKtn8rxfTs',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 5918,
#    'vicinity': 'Shopping Grande Rio - R. Maria Soares Sendas, 11 - Centro, São João de Meriti'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.8769997, 'lng': -43.2724116},
#     'viewport': {'northeast': {'lat': -22.87565217010728,
#       'lng': -43.27122697010727},
#      'southwest': {'lat': -22.87835182989272, 'lng': -43.27392662989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2171,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112809004784942574336">Roberto Almeida</a>'],
#      'photo_reference': 'AeeoHcLfaFKOqb-TLrO3xoTWol13fKKdiddDh3IGv_8DbAQyvZ8KXLwRFErn1N-bHVEX6CDScJXhFq1ds2GbMqDEE6hfIlWF0EcFjXmEa79VyeoKO7FCx2bFb-JkREjWDQ77NTsI2k8-sX8_Do3rqFIoXgNZYmi4vGWtD_I477BFhXs6JWYYVICLmuk_RxBnyjXAQXt-hDt6oRM0o9vTw6MuycJJSI2L5Jw69VYtSEE-tYnJxWQdn4AJWYkBl7wljQdBGpq7DOsEcOKnCL04wtbYcgBfnRwEKu8FhVjc3SOO6w5Lx3haMBE',
#      'width': 3283}],
#    'place_id': 'ChIJv9cZsr18mQARz-cvoSwrqWA',
#    'plus_code': {'compound_code': '4PFH+62 Inhaúma, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R4PFH+62'},
#    'rating': 4.3,
#    'reference': 'ChIJv9cZsr18mQARz-cvoSwrqWA',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 6696,
#    'vicinity': 'Av. Pastor Martin Luther King Jr., 126 - Inhaúma, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9193268, 'lng': -43.2501861},
#     'viewport': {'northeast': {'lat': -22.9175218, 'lng': -43.24901267010728},
#      'southwest': {'lat': -22.9211294, 'lng': -43.25171232989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105521753223989681840">Mari Maki</a>'],
#      'photo_reference': 'AeeoHcLRAUgWLPpqgJAB27mnWH0XcJgAWD5vhhqVSqmhNZSqMXNFCdCPnzamqzNwbu3xTETGqrECchBr_v7XRyweA5Mjuajiy2ZokixK-W3Uk2yZR9QC9ZMUMf6fNQYlvswcZ7j1BdwtWM3OpLQJVpjj28mAhip7sWs2ic9TpoKET07GZc7nFKwebcN1PiibEh49QeIgn7PXLoxHruQpMdZVNqKSxBaMaKXZ81B7KZ_IGU-y5eyXEp7ntT8YhM1j91I2dsSmHxKakN9kohvr29AyTFbxvh_XA9vYH1cQxsUfs5rgYyAqsbk',
#      'width': 4128}],
#    'place_id': 'ChIJD0_EK3V-mQAR_UlT2yeuUWM',
#    'plus_code': {'compound_code': '3PJX+7W Andaraí, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R3PJX+7W'},
#    'rating': 4.2,
#    'reference': 'ChIJD0_EK3V-mQAR_UlT2yeuUWM',
#    'scope': 'GOOGLE',
#    'types': ['department_store',
#     'shoe_store',
#     'point_of_interest',
#     'clothing_store',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2734,
#    'vicinity': 'R. Barão de São Francisco, 236 - Andaraí, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.8858818, 'lng': -43.285148},
#     'viewport': {'northeast': {'lat': -22.88442802010728,
#       'lng': -43.28351712010727},
#      'southwest': {'lat': -22.88712767989272, 'lng': -43.28621677989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2620,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111026569972967916502">A Google User</a>'],
#      'photo_reference': 'AeeoHcKTSBIDzIiBgcNJLEoh27A64XHmX8lL9Wr4Y98hIH1-U4TS0BItLSl458mbeIFRgvYXHL8GxLbZ61vCWDIq1gcehQY46EE27L8Qxsu_M5qhwa1XrjihsWlIZn39xk0WQHVz03p1YAVwcrO7SjTvHIN19GpeWaGtVWLajVf_uWLl3Ws6U5RuzZWRahbz8FCeWtbYL3RGJvH9k4G9VFPdnY47ut9ot-aCqmaZ-idNUXTtuOhX65LG7hNz-BL7htyxAuCdUKfftj7ilAUxCaUf0mH8PnQbXDfJRhCJMNz9KNQlfR6fnOc',
#      'width': 4656}],
#    'place_id': 'ChIJYUnhNlJ8mQAR0JYqsCBT7gU',
#    'plus_code': {'compound_code': '4P77+JW Del Castilho, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R4P77+JW'},
#    'rating': 4.3,
#    'reference': 'ChIJYUnhNlJ8mQAR0JYqsCBT7gU',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'department_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 7362,
#    'vicinity': 'Av. Dom Hélder Câmara, 5474 - Del Castilho, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9218629, 'lng': -43.2356409},
#     'viewport': {'northeast': {'lat': -22.92084447010728,
#       'lng': -43.23390667010727},
#      'southwest': {'lat': -22.92354412989272, 'lng': -43.23660632989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1948,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110855618528948577422">Bete Miguel</a>'],
#      'photo_reference': 'AeeoHcL7SQEENWDPXRpo1Oi1F-kxdKqp5GxhM0FBDc_jK5lJkq26Q22ARYMwH73K97BNmXB_Wm6RYCl_Qn3nx6Nn04hZVTMiTPVUpTX4ejTCCgNorbRF142k-t_qkamkdSDubwzS6cQn-b7mj-zoRclo30hFTxWb_mlL3KWGX4EchqkWoAV7g6P-fJAQzYM1M_3bCYi-SLNpImp8bRrkYv4ViXOlxc7ZMQEMLjej1e7snOt3UwI52mhDroX9g8ZjTgpX-FyQqbvaGiS-Cp0QnisnmIh6V8FdlrK_ec1MC5t4Og6JYKiJsBk',
#      'width': 3462}],
#    'place_id': 'ChIJbRMaCGt-mQAR6DwXZMrAOE8',
#    'plus_code': {'compound_code': '3QH7+7P Tijuca, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R3QH7+7P'},
#    'rating': 4.2,
#    'reference': 'ChIJbRMaCGt-mQAR6DwXZMrAOE8',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4642,
#    'vicinity': 'Shopping Tijuca - Av. Maracanã, 987 - Tijuca, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.870506, 'lng': -43.3409266},
#     'viewport': {'northeast': {'lat': -22.86882732010728,
#       'lng': -43.33948577010728},
#      'southwest': {'lat': -22.87152697989272, 'lng': -43.34218542989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1868,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117952879372082115690">Peter</a>'],
#      'photo_reference': 'AeeoHcK9_wbPUW9-hxRk944WWGyeolnaX0Tqq1g7U-P4MNpzSjDrb-v8ZU0TMofCAuEjfrzKgd6NiV7APtYiXRcgS4_pLSxuqDj1ME00ydI1_7LrKzIBKtshyWY7f6hNoUAUmO6RvX5Fl2K0wERu3jvCxixJ1q-7anOYahRnw-DLbpOQ33sL9YJdVuLOolOG4w_FIMD1LxHxAkIzsqWdFXAW9LMhej2y66VXLQ-g9jxsdwPQOuIizQCfDDNxDRtSCIdrinH7_cdTDgIpkwLJcTV5kYxdz7-_UzQ61tv_TGc-bpCC7qHp4Ww',
#      'width': 4000}],
#    'place_id': 'ChIJ6brOh9himQARd4rfNJiDuvM',
#    'plus_code': {'compound_code': '4MH5+QJ Madureira, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R4MH5+QJ'},
#    'rating': 4.3,
#    'reference': 'ChIJ6brOh9himQARd4rfNJiDuvM',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 5745,
#    'vicinity': 'Estr. do Portela, 222 - Madureira, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.7525494, 'lng': -43.4542606},
#     'viewport': {'northeast': {'lat': -22.75136602010728,
#       'lng': -43.45316262010728},
#      'southwest': {'lat': -22.75406567989272, 'lng': -43.45586227989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101664449699513616575">renan reis</a>'],
#      'photo_reference': 'AeeoHcIGo5_J2Qnqoze0qKxBPRC7sJeJSftPosjldaGA76dgiVuiD7BhQzJF5tC-J5RRxSKGaE5A77fPi62SmeQ8wNfcFX5a70mvYSzofy_az1vTwTdW2I8xqNkxbmhxphRz0VEJiLEuylA8Kyfs6NsXY9JvgIGX-9M89JTpPaeMZLt80jh8nn7k8YUHUjP84b1kz4AI-MfpA30giz0IGbuCYyApHx5EMFVHLaf7Yj5vPud0VwdEsH6NcKTh1ztn70TTMr0j8fzvNBABNC7suMv12qL6qgLLWoxgOf9wOycGPLTucY5IV1Y',
#      'width': 640}],
#    'place_id': 'ChIJPagBY6hnmQARRK7w8u7d-Fg',
#    'plus_code': {'compound_code': '6GWW+X7 Centro, Nova Iguaçu - State of Rio de Janeiro',
#     'global_code': '589R6GWW+X7'},
#    'rating': 4.4,
#    'reference': 'ChIJPagBY6hnmQARRK7w8u7d-Fg',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2824,
#    'vicinity': 'Av. Gov. Roberto Silveira, 540 - Loja A102 / 4 / 109 - Centro, Nova Iguaçu'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.8206093, 'lng': -43.0462572},
#     'viewport': {'northeast': {'lat': -22.81937317010728,
#       'lng': -43.04491502010727},
#      'southwest': {'lat': -22.82207282989272, 'lng': -43.04761467989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1533,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112809004784942574336">Roberto Almeida</a>'],
#      'photo_reference': 'AeeoHcLg5LHQBJWF7AJY4HK5RjhIHtkMPssHyiDz1vWCK4vW8vNjjTC_IaeadGCK24i1RCeLVoNcitWo83yE84LKI8AcQejXOleVbmN3Pz13luGLXhG9xiTiv5TsvCRS7GOgjkQSV54yz1qAsVMxkSHC5hfWudDpQCeQMgoXjl4Oc6mS8PggW0GWZ_7NlyXSV5F1CLLmxKauVE3gMaBd_G2GFOD2HSN0zf923IP35nU8Ik-YUW3Qrcy4YAmQPkAAJ3Zz79tmgYQ1n106VYitQLgkYQE9-6c40nBh1QcufNgc89IXORkysw8',
#      'width': 2917}],
#    'place_id': 'ChIJMT7m0vaamQAR_FU9OywkwrA',
#    'plus_code': {'compound_code': '5XH3+QF Centro, São Gonçalo - State of Rio de Janeiro',
#     'global_code': '589R5XH3+QF'},
#    'rating': 4.3,
#    'reference': 'ChIJMT7m0vaamQAR_FU9OywkwrA',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'department_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2670,
#    'vicinity': 'Shopping Boulevard - Av. Pres. Kennedy, 425 - Centro, São Gonçalo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.8498805, 'lng': -43.31091370000001},
#     'viewport': {'northeast': {'lat': -22.84862087010728,
#       'lng': -43.30961607010728},
#      'southwest': {'lat': -22.85132052989272, 'lng': -43.31231572989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109359736390262439427">Yuri Castro</a>'],
#      'photo_reference': 'AeeoHcIyijUySsZMag5mV0QBDBgXlavFA6lo1wOlS8PMhZyyXbnyrY3dKhHLJptFsmsyMbnErvn2crNKBGa104VJ4JacTdAtXxZhLIQvSfx5kU_6MMRMcVJ0ehicyPK-8-fqCwkqLbuTksm63Ubk-C5n2-Nl5wqC3gPk9wfYIhfOZstJZxP3I29LeI3mLygtJMKEcZUPyuUa5h71CcMgdvSmtldY8rB3_yrqpRc6aPpseCAs9eF8O7ZojNvGULp43DL1xyJA0cjHvk2pK7VNFswbxHgVmbcuaxEZtdwz36DiFc_N8y3t6ZQ',
#      'width': 2592}],
#    'place_id': 'ChIJgwgT8aJ8mQARYWhWqpBK2E4',
#    'plus_code': {'compound_code': '5M2Q+2J Vila da Penha, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R5M2Q+2J'},
#    'rating': 4.3,
#    'reference': 'ChIJgwgT8aJ8mQARYWhWqpBK2E4',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 3766,
#    'vicinity': 'Carioca Shopping - Av. Vicente de Carvalho, 909 - Vila da Penha, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.768148, 'lng': -42.905559},
#     'viewport': {'northeast': {'lat': -22.76631387010728,
#       'lng': -42.90479122010728},
#      'southwest': {'lat': -22.76901352989272, 'lng': -42.90749087989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114773664621794935486">Vinícius Messias</a>'],
#      'photo_reference': 'AeeoHcK3lncv0kfxhiv9XhEZfnRKZ7fe12FkEGQnJeJGWXVkHgjACX5W7oW97ZYZZ1xc79qkhMoyb7NsJk36MnJ90wk6_j0ydaG-wCQX7ltaf2YAVTLokHTeS4R7631vnBD1VWKdg1xIWAlCuR-a85S8y0z31h3nSyvGJP_X8i5A2QapwYZHVRNpPQQkaRpgXBBNyUeBKWhCaVOii9TG1juH0s1-0mYEPh_tRWBYIJwjQ4a49cCx3BvKk0oqNzplyLbHokpte-8EP9cfn3gPrAEks1aihQAiJU1wzxz2pxfSr4o3zBvNa4c',
#      'width': 1280}],
#    'place_id': 'ChIJoZVz0aGVmQARqajB08oDD5Y',
#    'plus_code': {'compound_code': '63JV+PQ Centro, Itaboraí - State of Rio de Janeiro',
#     'global_code': '589V63JV+PQ'},
#    'rating': 4.3,
#    'reference': 'ChIJoZVz0aGVmQARqajB08oDD5Y',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2138,
#    'vicinity': 'BR-101, 5, Shopping Itaboraí Plaza - Centro, Itaboraí'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9820681, 'lng': -43.3628559},
#     'viewport': {'northeast': {'lat': -22.98089472010728,
#       'lng': -43.36111842010727},
#      'southwest': {'lat': -22.98359437989272, 'lng': -43.36381807989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114546401918675337619">cris andrade</a>'],
#      'photo_reference': 'AeeoHcIz7u4hzSIzfir6aS-2nhZq11d39R_FkqVltbnGXwI2xHnclHt1O0Qpn_b5cmIj_yQom2VfODPn3wEmTZKpidNBF7cnXwvEvU_7Muenk-pJ-rER0DQTKlyBX8ArxXy9VE8j8LLkMQ-6x4IhZ_Nh4kCZbb0eN-AsN2ozt6ZUFBCYBrWKioRrfKF6m1mh9whszBPp3Fc7AoOzUm9lNm-VurXUxiPSERUMc2n9G2FkMbHAFm1bzL-5R1E8xpKiISVfYbLS5gfBD8bawFLt-E3lsk7na35fLlkLp0hHzJYGprYHbWZY4qE',
#      'width': 4160}],
#    'place_id': 'ChIJFdjApS7amwARWFD01EYt7eM',
#    'plus_code': {'compound_code': '2J9P+5V Rio de Janeiro, State of Rio de Janeiro',
#     'global_code': '589R2J9P+5V'},
#    'rating': 4.3,
#    'reference': 'ChIJFdjApS7amwARWFD01EYt7eM',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 2981,
#    'vicinity': 'Av. Ayrton Senna, 3000 - Barra da Tijuca, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -23.0119956, 'lng': -43.461621},
#     'viewport': {'northeast': {'lat': -23.01077997010728,
#       'lng': -43.46010057010729},
#      'southwest': {'lat': -23.01347962989272, 'lng': -43.46280022989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103507141631659856653">augusto nasajon</a>'],
#      'photo_reference': 'AeeoHcJ4nVBHlNgdqJDgph2q0wuqojfxgD3SYZBNn1GxvIUcukcjfs9D0C4Ue1ggU7Nk5K0AlRK90PYAogPGYagvQ1a_5NKhbN9oHCVW0WMn7L0cap68S21svWa6uu7RckjgLhSw04sKiDqrkF5y-cbW-mQuVod2TWlQIx2ySxmKqH6qbi7FcdV3CXH7gZz0k7JhwKzGlFPDfc8laCLuwWokRHDK5doSRjKLRCmgoIS7dBX05iW4wpJt58XAFzkgXLMQJPp_D_yxS2x3t0yEFMiSwTLhrlA85YvUYilL55_rdb7T8mRM1Xg',
#      'width': 3120}],
#    'place_id': 'ChIJaXpPAzfdmwARf5eo6PT3IuI',
#    'plus_code': {'compound_code': 'XGQQ+69 Recreio dos Bandeirantes, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '588RXGQQ+69'},
#    'rating': 4.2,
#    'reference': 'ChIJaXpPAzfdmwARf5eo6PT3IuI',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1906,
#    'vicinity': 'Avenida das Américas 15500, Américas Shopping - Recreio dos Bandeirantes, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9250927, 'lng': -43.3611752},
#     'viewport': {'northeast': {'lat': -22.92356232010728,
#       'lng': -43.35972682010728},
#      'southwest': {'lat': -22.92626197989272, 'lng': -43.36242647989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116958556389173786703">116958556389173786703</a>'],
#      'photo_reference': 'AeeoHcLavjsX1GgOkBlqspTJN6jEnnJpE0aVFbfJBJMDZZQvEmS6rt-XVJRYDPLCzw7WYwjGAfIRCI4Z5tUb_pi_jPmiZwQzMs15WCwbnMsOmMnGpuFF71VSw4MF5iTfS2zUYyyo9XE61tqGgORPbfwkYOcah5NmscQ-cYqtaeMFjdEshHNyvzsV_Dfsgu8V5_CP1uODA_Z_Fw9qn_mEYo6UbcJcYdWgQw0mZMvG7TKGYGkSxjYQ8OYLB7SZ5EruXdrpZn2GsU-P_co50mKsEVUPyi4nfs0ybfDlwOzn7yAdgObpIp7KfDs',
#      'width': 1920}],
#    'place_id': 'ChIJ8Sgl-WbYmwARaxLU3m7rQ80',
#    'plus_code': {'compound_code': '3JFQ+XG Tanque, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R3JFQ+XG'},
#    'rating': 4.2,
#    'reference': 'ChIJ8Sgl-WbYmwARaxLU3m7rQ80',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 1421,
#    'vicinity': 'Center Shopping - Av. Geremário Dantas, 404 - Tanque, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9281323, 'lng': -43.5743836},
#     'viewport': {'northeast': {'lat': -22.9261455, 'lng': -43.5726476},
#      'southwest': {'lat': -22.9288671, 'lng': -43.57804359999999}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106664123076376328945">Eron Barreto Eronbp</a>'],
#      'photo_reference': 'AeeoHcLuqbwVlfyRcMd12IKou3KZzwhh7JkQyKzC__VvgXm_WtYQJKLWKliSgjBsS1D6psKI8iOwM898IkUp90kvQQQpW0RGT_3P2oZp9FZh76kQgJFmErLT3YKxK-Qm2MYcFuziEybBTQKNtDsmkl8lgXBGqsfVPp8K28ccMODZcGbHdu9VGyp0FM--utziJWomhEBeDs-PQESIi6Mb0pRkzUKcBVuzLAFKFayNxUM_c1EARFtdaFCfOD7_ckcu1-0im2jDHmyopQoZJ80OnFnddLHcc1djjL_lq7xLsTGnlsXtH6syOJ4',
#      'width': 1920}],
#    'place_id': 'ChIJScbuFjzkmwARXMgELsQ8LSg',
#    'plus_code': {'compound_code': '3CCG+P6 Campo Grande, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R3CCG+P6'},
#    'rating': 4.4,
#    'reference': 'ChIJScbuFjzkmwARXMgELsQ8LSg',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'department_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 6033,
#    'vicinity': 'Estr. do Monteiro, 1200 - Campo Grande, Rio de Janeiro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.8017399, 'lng': -43.2015766},
#     'viewport': {'northeast': {'lat': -22.80029862010727,
#       'lng': -43.20043662010728},
#      'southwest': {'lat': -22.80299827989272, 'lng': -43.20313627989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#    'icon_background_color': '#4B96F3',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#    'name': 'Lojas Renner',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116303208605387112401">Edson Eduardo Dudu</a>'],
#      'photo_reference': 'AeeoHcIS0s8BM5aUFTeGyVmiboigx2WPwenI-td6IKtnJaA4gtElgga5LRUduw46SDEwMoDKEGrIqFMd8WuzweU2jqJMj15nu9jv1KTKgyJ34GuhxVm8z0DHAKKFz1N5Uy9TlpCNAAO_M7kPL4K88MY4PBJtdtnVszKEskpmlOR4hnKXo_XF41UKkMrlKtmHdx8ZR9gQaqK_8pbR0Jur0Jfl3QdeoJVGai96xFZrztGtdPbCJke6EDHTJ0ikNXBgAYdCVDLJEhbcOMhu302WioNxczZi6gTKEbhCA6mNJ0_2eyzNCJUZp94',
#      'width': 1920}],
#    'place_id': 'ChIJn2eg9yd4mQARGnGGMtZy34o',
#    'plus_code': {'compound_code': '5QXX+89 Jardim Carioca, Rio de Janeiro - State of Rio de Janeiro',
#     'global_code': '589R5QXX+89'},
#    'rating': 4.2,
#    'reference': 'ChIJn2eg9yd4mQARGnGGMtZy34o',
#    'scope': 'GOOGLE',
#    'types': ['clothing_store',
#     'shoe_store',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 3550,
#    'vicinity': 'Avenida Maestro Paulo e Silva, 400 - Freguesia (Ilha do Governador - Jardim Carioca, Rio de Janeiro'}],
#  'status': 'OK'}

# %%
nome_sheet = 'Lista de Lojas | Stores List'

planilha_renner = pd.read_excel("lojas_renner.xlsx", sheet_name = nome_sheet, skiprows = 5, 
                                usecols = ['Business', 'Country', 'UF', 'State', 'City'])

planilha_renner

# %%
planilha_renner = planilha_renner.dropna()

planilha_renner = planilha_renner[(planilha_renner['Business'] == "Renner") & 
                                  (planilha_renner['Country'] == "Brazil")]

planilha_renner

# %%
planilha_renner['enderecos'] = (planilha_renner[['City', 'State', 'UF', 'Country']].
                                apply(lambda row: '-'.join(row.values.astype(str)), axis=1))

enderecos_cidades_renner = list(planilha_renner['enderecos'].unique())

enderecos_cidades_renner

# %%
lista_cordenadas = []

for endereco in enderecos_cidades_renner:

    response = cliente.geocode(endereco)

    latitude = response[0]['geometry']['location']['lat']
    longitude = response[0]['geometry']['location']['lng']
    
    coordenadas = (latitude, longitude)
    
    lista_cordenadas.append(coordenadas)
    
    
lista_cordenadas

# %%
lista_dfs = []

for coordenada in lista_cordenadas:
    
    print(coordenada)
    
    results = cliente.places_nearby(location = coordenada, 
                                  keyword = "Lojas Renner", radius = 50000)


    while True:
        
        time.sleep(2)

        for store in results['results']:

            df = pd.DataFrame({'nome': store['name'],
                          'endereco': store['vicinity'],
                          'latitude': store['geometry']['location']['lat'],
                          'longitudade': store['geometry']['location']['lng']}, index = [0])

            lista_dfs.append(df)

        if 'next_page_token' in results:
            next_page_token = results['next_page_token']
            results = cliente.places_nearby(location = coordenada, 
                                  keyword = "Lojas Renner", radius = 50000, page_token = next_page_token)

        else:
            break
        
lojas_renner = pd.concat(lista_dfs, ignore_index = True)

lojas_renner

# %%
lojas_renner_filtrado = lojas_renner[(lojas_renner['nome'] == "Renner") |
                                    (lojas_renner['nome'] == "Lojas Renner") |
                                    (lojas_renner['nome'] == "lojas renner")]

lojas_renner_filtrado = lojas_renner_filtrado.drop_duplicates(subset = ['endereco'])

# %%
coordenadas_lojas = lojas_renner_filtrado[['latitude', 'longitudade']].values
coordenadas_lojas

# %%
# %pip install folium

# %%
import folium
from folium.plugins import HeatMap

# %%
mapa = folium.Map(location = [-9.026078, -70.441312], zoom_start = 6)

HeatMap(coordenadas_lojas, radius = 50).add_to(mapa)

mapa.save('heatmap_renner.html')

# %% [markdown]
# # Riachuelo

# %%
nome_sheet = 'Lojas'

planilha_riachu = pd.read_excel("riachuelo.xlsx", sheet_name = nome_sheet, skiprows = 4, 
                               usecols = ['Marcas', 'Estado', 'Cidade'])

planilha_riachu = planilha_riachu.dropna()

planilha_riachu = planilha_riachu[planilha_riachu['Marcas'] == "Riachuelo"]  
               
planilha_riachu['enderecos'] = (planilha_riachu[['Cidade', 'Estado']].
                                apply(lambda row: '- '.join(row.values.astype(str)), axis=1))

enderecos_cidades_riachu = list(planilha_riachu['enderecos'].unique())

enderecos_cidades_riachu.remove("Sinop - Sinop")
enderecos_cidades_riachu.append("Sinop - Mato Grosso do Sul")

lista_cordenadas_riachu = []

for endereco in enderecos_cidades_riachu:

    response = cliente.geocode(endereco)

    latitude = response[0]['geometry']['location']['lat']
    longitude = response[0]['geometry']['location']['lng']
    
    coordenadas = (latitude, longitude)
    
    lista_cordenadas.append(coordenadas)

    
lista_dfs = []

for coordenada in lista_cordenadas_riachu:
    
    print(coordenada)
    
    results = cliente.places_nearby(location = coordenada, 
                                  keyword = "Riachuelo", radius = 50000)


    while True:
        
        time.sleep(0.5)

        for store in results['results']:

            df = pd.DataFrame({'nome': store['name'],
                          'endereco': store['vicinity'],
                          'latitude': store['geometry']['location']['lat'],
                          'longitudade': store['geometry']['location']['lng']}, index = [0])

            lista_dfs.append(df)

        if 'next_page_token' in results:
            next_page_token = results['next_page_token']
            results = cliente.places_nearby(location = coordenada, 
                                  keyword = "Riachuelo", radius = 50000, page_token = next_page_token)

        else:
            break
        
lojas_riachu = pd.concat(lista_dfs, ignore_index = True)

lojas_riachu_filtrado = lojas_riachu[(lojas_riachu['nome'] == "Riachuelo") |
                                    (lojas_riachu['nome'] == "RIACHUELO") |
                                    (lojas_riachu['nome'] == "riachuelo") |
                                    (lojas_riachu['nome'] == "riachuelo")]

lojas_riachu_filtrado = lojas_riachu_filtrado.drop_duplicates(subset = ['endereco'])

coordenadas_lojas_riachu = lojas_riachu_filtrado[['latitude', 'longitudade']].values

mapa_ri = folium.Map(location = [-9.026078, -70.441312], zoom_start = 6)

HeatMap(coordenadas_lojas_riachu, radius = 50).add_to(mapa_ri)

mapa_ri.save('heatmap_riachuelo.html')

# %% [markdown]
# # Quero Quero

# %%
nome_sheet = 'Lojas'

planilha_qq = pd.read_excel("quero_quero.xlsx", sheet_name = nome_sheet, skiprows = 2, 
                               usecols = ['Cidade (UF)', 'Estado'])

planilha_qq = planilha_qq.dropna()

planilha_qq['Cidade (UF)'] = planilha_qq['Cidade (UF)'].str.replace(r"\(.*\)", '') 

planilha_qq['enderecos'] = (planilha_qq[['Cidade (UF)', 'Estado']].
                                apply(lambda row: '- '.join(row.values.astype(str)), axis=1))

lista_enderecos_qq = list(planilha_qq['enderecos'].unique())

lista_cordenadas_qq = []

for endereco in lista_enderecos_qq:

    response = cliente.geocode(endereco)

    if response != []:

        latitude = response[0]['geometry']['location']['lat']
        longitude = response[0]['geometry']['location']['lng']

        coordenadas = (latitude, longitude)

        lista_cordenadas_qq.append(coordenadas)

lista_dfs = []

for coordenada in lista_cordenadas_qq:
    
    print(coordenada)
    
    results = cliente.places_nearby(location = coordenada, 
                                  keyword = "lojas quero quero", radius = 50000)


    while True:
        
        time.sleep(0.5)

        for store in results['results']:

            df = pd.DataFrame({'nome': store['name'],
                          'endereco': store['vicinity'],
                          'latitude': store['geometry']['location']['lat'],
                          'longitudade': store['geometry']['location']['lng']}, index = [0])

            lista_dfs.append(df)

        if 'next_page_token' in results:
            next_page_token = results['next_page_token']
            results = cliente.places_nearby(location = coordenada, 
                                  keyword = "lojas quero quero", radius = 50000, page_token = next_page_token)

        else:
            break
        
lojas_qq = pd.concat(lista_dfs, ignore_index = True)

lojas_qq_filtrado = lojas_qq[(lojas_qq['nome'] == "Lojas Quero-Quero") |
                                    (lojas_qq['nome'].str.contains("Construção"))]

lojas_qq_filtrado = lojas_qq_filtrado.drop_duplicates(subset = ['endereco'])

coordenadas_lojas_qq = lojas_qq_filtrado[['latitude', 'longitudade']].values

mapa_qq = folium.Map(location = [-9.026078, -70.441312], zoom_start = 6)

HeatMap(coordenadas_lojas_qq, radius = 50).add_to(mapa_qq)

mapa_qq.save('heatmap_qq.html')
